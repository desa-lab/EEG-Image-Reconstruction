# %%
import matplotlib.pyplot as plt
import numpy as np
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### Value entries

# %%
avg1_200ms_pixcorr = 0.13815263313581144
avg1_200ms_ssim = 0.3293977801714336
avg1_200ms_alexnet_2_corr = 0.7665577889447236 
avg1_200ms_alexnet_5_corr = 0.8039447236180906 
avg1_200ms_inceptionv3_avgpool_corr = 0.6112311557788945
avg1_200ms_clip_final_corr = 0.6669346733668342 
avg1_200ms_efficientnet_avgpool_dist = 0.9407112052135562
avg1_200ms_swav_avgpool_dist = 0.6192046430706978

avg1_200ms = np.array([avg1_200ms_pixcorr, avg1_200ms_ssim, avg1_200ms_alexnet_2_corr, avg1_200ms_alexnet_5_corr, avg1_200ms_inceptionv3_avgpool_corr, avg1_200ms_clip_final_corr, avg1_200ms_efficientnet_avgpool_dist, avg1_200ms_swav_avgpool_dist])

# %%
avg1_400ms_pixcorr = 0.1594955272347989
avg1_400ms_ssim = 0.3260979016060166
avg1_400ms_alexnet_2_corr = 0.7983919597989949
avg1_400ms_alexnet_5_corr = 0.844070351758794
avg1_400ms_inceptionv3_avgpool_corr = 0.6552763819095477
avg1_400ms_clip_final_corr = 0.7311809045226131
avg1_400ms_efficientnet_avgpool_dist = 0.9251491081259883
avg1_400ms_swav_avgpool_dist = 0.5963052975386381

avg1_400ms = np.array([avg1_400ms_pixcorr, avg1_400ms_ssim, avg1_400ms_alexnet_2_corr, avg1_400ms_alexnet_5_corr, avg1_400ms_inceptionv3_avgpool_corr, avg1_400ms_clip_final_corr, avg1_400ms_efficientnet_avgpool_dist, avg1_400ms_swav_avgpool_dist])

# %%
avg1_600ms_pixcorr = 0.15665747465837893
avg1_600ms_ssim = 0.3288369196647705
avg1_600ms_alexnet_2_corr = 0.8098994974874372
avg1_600ms_alexnet_5_corr = 0.8472613065326633
avg1_600ms_inceptionv3_avgpool_corr = 0.6506281407035176
avg1_600ms_clip_final_corr = 0.7281155778894473
avg1_600ms_efficientnet_avgpool_dist = 0.921192955665756
avg1_600ms_swav_avgpool_dist = 0.5943310198187828

avg1_600ms = np.array([avg1_600ms_pixcorr, avg1_600ms_ssim, avg1_600ms_alexnet_2_corr, avg1_600ms_alexnet_5_corr, avg1_600ms_inceptionv3_avgpool_corr, avg1_600ms_clip_final_corr, avg1_600ms_efficientnet_avgpool_dist, avg1_600ms_swav_avgpool_dist])

# %%
avg1_800ms_pixcorr = 0.1512113787870312
avg1_800ms_ssim = 0.32732701363579225
avg1_800ms_alexnet_2_corr = 0.8045226130653266
avg1_800ms_alexnet_5_corr = 0.8514321608040201
avg1_800ms_inceptionv3_avgpool_corr = 0.643391959798995
avg1_800ms_clip_final_corr = 0.7308291457286432
avg1_800ms_efficientnet_avgpool_dist = 0.9159626523466432
avg1_800ms_swav_avgpool_dist = 0.5923028722405433

avg1_800ms = np.array([avg1_800ms_pixcorr, avg1_800ms_ssim, avg1_800ms_alexnet_2_corr, avg1_800ms_alexnet_5_corr, avg1_800ms_inceptionv3_avgpool_corr, avg1_800ms_clip_final_corr, avg1_800ms_efficientnet_avgpool_dist, avg1_800ms_swav_avgpool_dist])

# %%
preproc_200ms_pixcorr = 0.16378334114017862
preproc_200ms_ssim = 0.34083094039444917
preproc_200ms_alexnet_2_corr = 0.8098241206030151
preproc_200ms_alexnet_5_corr = 0.8513065326633166
preproc_200ms_inceptionv3_avgpool_corr = 0.6402261306532664
preproc_200ms_clip_final_corr = 0.6811055276381909
preproc_200ms_efficientnet_avgpool_dist = 0.9341311216163013
preproc_200ms_swav_avgpool_dist = 0.6085036493092776

preproc_200ms = np.array([preproc_200ms_pixcorr, preproc_200ms_ssim, preproc_200ms_alexnet_2_corr, preproc_200ms_alexnet_5_corr, preproc_200ms_inceptionv3_avgpool_corr, preproc_200ms_clip_final_corr, preproc_200ms_efficientnet_avgpool_dist, preproc_200ms_swav_avgpool_dist])

# %%
preproc_400ms_pixcorr = 0.21019476025313885
preproc_400ms_ssim = 0.3405437183790763
preproc_400ms_alexnet_2_corr = 0.8531658291457287
preproc_400ms_alexnet_5_corr = 0.8876381909547738
preproc_400ms_inceptionv3_avgpool_corr = 0.6729145728643215
preproc_400ms_clip_final_corr = 0.7393718592964824
preproc_400ms_efficientnet_avgpool_dist = 0.9130800152282245
preproc_400ms_swav_avgpool_dist = 0.5821823760122061

preproc_400ms = np.array([preproc_400ms_pixcorr, preproc_400ms_ssim, preproc_400ms_alexnet_2_corr, preproc_400ms_alexnet_5_corr, preproc_400ms_inceptionv3_avgpool_corr, preproc_400ms_clip_final_corr, preproc_400ms_efficientnet_avgpool_dist, preproc_400ms_swav_avgpool_dist])

# %%
preproc_600ms_pixcorr = 0.21039430682459462
preproc_600ms_ssim = 0.339764443476961
preproc_600ms_alexnet_2_corr = 0.8576130653266332
preproc_600ms_alexnet_5_corr = 0.9055527638190956
preproc_600ms_inceptionv3_avgpool_corr = 0.6833668341708543
preproc_600ms_clip_final_corr = 0.7482914572864321
preproc_600ms_efficientnet_avgpool_dist = 0.9103562442096882
preproc_600ms_swav_avgpool_dist = 0.5747930534183979

preproc_600ms = np.array([preproc_600ms_pixcorr, preproc_600ms_ssim, preproc_600ms_alexnet_2_corr, preproc_600ms_alexnet_5_corr, preproc_600ms_inceptionv3_avgpool_corr, preproc_600ms_clip_final_corr, preproc_600ms_efficientnet_avgpool_dist, preproc_600ms_swav_avgpool_dist])

# %%
preproc_800ms_pixcorr = 0.20929263640910903
preproc_800ms_ssim = 0.34006651623870204
preproc_800ms_alexnet_2_corr = 0.8478894472361809
preproc_800ms_alexnet_5_corr = 0.8944723618090452
preproc_800ms_inceptionv3_avgpool_corr = 0.6765829145728642
preproc_800ms_clip_final_corr = 0.7492211055276382
preproc_800ms_efficientnet_avgpool_dist = 0.9121800053943298
preproc_800ms_swav_avgpool_dist = 0.5758596473932266

preproc_800ms = np.array([preproc_800ms_pixcorr, preproc_800ms_ssim, preproc_800ms_alexnet_2_corr, preproc_800ms_alexnet_5_corr, preproc_800ms_inceptionv3_avgpool_corr, preproc_800ms_clip_final_corr, preproc_800ms_efficientnet_avgpool_dist, preproc_800ms_swav_avgpool_dist])

# %%
preproc2_800ms_pixcorr = 0.19192962592975094
preproc2_800ms_ssim = 0.3498065737805734
preproc2_800ms_alexnet_2_corr = 0.8212562814070352
preproc2_800ms_alexnet_5_corr = 0.8739949748743719
preproc2_800ms_inceptionv3_avgpool_corr = 0.6558291457286431
preproc2_800ms_clip_final_corr = 0.7427889447236181
preproc2_800ms_efficientnet_avgpool_dist = 0.9162738777389677
preproc2_800ms_swav_avgpool_dist = 0.587867431640625

preproc2_800ms = np.array([preproc2_800ms_pixcorr, preproc2_800ms_ssim, preproc2_800ms_alexnet_2_corr, preproc2_800ms_alexnet_5_corr, preproc2_800ms_inceptionv3_avgpool_corr, preproc2_800ms_clip_final_corr, preproc2_800ms_efficientnet_avgpool_dist, preproc2_800ms_swav_avgpool_dist])

# %%
preproc3_800ms_pixcorr = 0.20781705556007865
preproc3_800ms_ssim = 0.3507597505695798
preproc3_800ms_alexnet_2_corr = 0.8619597989949749
preproc3_800ms_alexnet_5_corr = 0.8868341708542713
preproc3_800ms_inceptionv3_avgpool_corr = 0.6967587939698493
preproc3_800ms_clip_final_corr = 0.7517839195979898
preproc3_800ms_efficientnet_avgpool_dist = 0.9019380372369779
preproc3_800ms_swav_avgpool_dist = 0.5707650122791529

preproc3_800ms = np.array([preproc3_800ms_pixcorr, preproc3_800ms_ssim, preproc3_800ms_alexnet_2_corr, preproc3_800ms_alexnet_5_corr, preproc3_800ms_inceptionv3_avgpool_corr, preproc3_800ms_clip_final_corr, preproc3_800ms_efficientnet_avgpool_dist, preproc3_800ms_swav_avgpool_dist])

# %%
preproc4_800ms_pixcorr = 0.19897894311159559
preproc4_800ms_ssim = 0.34274435696278516
preproc4_800ms_alexnet_2_corr = 0.8365326633165829
preproc4_800ms_alexnet_5_corr = 0.8923366834170854
preproc4_800ms_inceptionv3_avgpool_corr = 0.707889447236181
preproc4_800ms_clip_final_corr = 0.7765577889447236
preproc4_800ms_efficientnet_avgpool_dist = 0.9064431399098066
preproc4_800ms_swav_avgpool_dist = 0.5791867253929377

preproc4_800ms = np.array([preproc4_800ms_pixcorr, preproc4_800ms_ssim, preproc4_800ms_alexnet_2_corr, preproc4_800ms_alexnet_5_corr, preproc4_800ms_inceptionv3_avgpool_corr, preproc4_800ms_clip_final_corr, preproc4_800ms_efficientnet_avgpool_dist, preproc4_800ms_swav_avgpool_dist])

# %%
preproc5_800ms_pixcorr = 0.18631166127673182
preproc5_800ms_ssim = 0.3540331948550753
preproc5_800ms_alexnet_2_corr = 0.8210804020100503
preproc5_800ms_alexnet_5_corr = 0.8546482412060301
preproc5_800ms_inceptionv3_avgpool_corr = 0.6665577889447236
preproc5_800ms_clip_final_corr = 0.7209547738693467
preproc5_800ms_efficientnet_avgpool_dist = 0.9179244018584722
preproc5_800ms_swav_avgpool_dist = 0.5934741246700287

preproc5_800ms = np.array([preproc5_800ms_pixcorr, preproc5_800ms_ssim, preproc5_800ms_alexnet_2_corr, preproc5_800ms_alexnet_5_corr, preproc5_800ms_inceptionv3_avgpool_corr, preproc5_800ms_clip_final_corr, preproc5_800ms_efficientnet_avgpool_dist, preproc5_800ms_swav_avgpool_dist])

# %%
preproc6_800ms_pixcorr = 0.21112137785198318
preproc6_800ms_ssim = 0.3492201983311116
preproc6_800ms_alexnet_2_corr = 0.8676633165829145
preproc6_800ms_alexnet_5_corr = 0.8969849246231156
preproc6_800ms_inceptionv3_avgpool_corr = 0.6855527638190956
preproc6_800ms_clip_final_corr = 0.7687688442211056
preproc6_800ms_efficientnet_avgpool_dist = 0.8989465748592557
preproc6_800ms_swav_avgpool_dist = 0.5714249118417501

preproc6_800ms = np.array([preproc6_800ms_pixcorr, preproc6_800ms_ssim, preproc6_800ms_alexnet_2_corr, preproc6_800ms_alexnet_5_corr, preproc6_800ms_inceptionv3_avgpool_corr, preproc6_800ms_clip_final_corr, preproc6_800ms_efficientnet_avgpool_dist, preproc6_800ms_swav_avgpool_dist])

# %%
preproc7_800ms_pixcorr = 0.1507042963946205
preproc7_800ms_ssim = 0.3472295101548602
preproc7_800ms_alexnet_2_corr = 0.8313819095477386
preproc7_800ms_alexnet_5_corr = 0.88821608040201
preproc7_800ms_inceptionv3_avgpool_corr = 0.6968844221105528  
preproc7_800ms_clip_final_corr = 0.7329145728643216
preproc7_800ms_efficientnet_avgpool_dist = 0.9111829391360515
preproc7_800ms_swav_avgpool_dist = 0.587709845006466

preproc7_800ms = np.array([preproc7_800ms_pixcorr, preproc7_800ms_ssim, preproc7_800ms_alexnet_2_corr, preproc7_800ms_alexnet_5_corr, preproc7_800ms_inceptionv3_avgpool_corr, preproc7_800ms_clip_final_corr, preproc7_800ms_efficientnet_avgpool_dist, preproc7_800ms_swav_avgpool_dist])

# %%
preproc8_800ms_pixcorr = 0.22887480828653353
preproc8_800ms_ssim = 0.3561221624489349
preproc8_800ms_alexnet_2_corr = 0.8582412060301507
preproc8_800ms_alexnet_5_corr = 0.8984170854271356
preproc8_800ms_inceptionv3_avgpool_corr = 0.6794221105527639
preproc8_800ms_clip_final_corr = 0.7636934673366834
preproc8_800ms_efficientnet_avgpool_dist = 0.9018592780170729
preproc8_800ms_swav_avgpool_dist = 0.5736695002764464

preproc8_800ms = np.array([preproc8_800ms_pixcorr, preproc8_800ms_ssim, preproc8_800ms_alexnet_2_corr, preproc8_800ms_alexnet_5_corr, preproc8_800ms_inceptionv3_avgpool_corr, preproc8_800ms_clip_final_corr, preproc8_800ms_efficientnet_avgpool_dist, preproc8_800ms_swav_avgpool_dist])

# %%
preproc9_800ms_pixcorr = 0.2088677348339617
preproc9_800ms_ssim = 0.3481182766381853
preproc9_800ms_alexnet_2_corr = 0.8380150753768844
preproc9_800ms_alexnet_5_corr = 0.885603015075377
preproc9_800ms_inceptionv3_avgpool_corr = 0.6700753768844221
preproc9_800ms_clip_final_corr = 0.735251256281407
preproc9_800ms_efficientnet_avgpool_dist = 0.9012673135130899
preproc9_800ms_swav_avgpool_dist = 0.5776492658257485

preproc9_800ms = np.array([preproc9_800ms_pixcorr, preproc9_800ms_ssim, preproc9_800ms_alexnet_2_corr, preproc9_800ms_alexnet_5_corr, preproc9_800ms_inceptionv3_avgpool_corr, preproc9_800ms_clip_final_corr, preproc9_800ms_efficientnet_avgpool_dist, preproc9_800ms_swav_avgpool_dist])

# %%
preproc10_800ms_pixcorr = 0.20677378967294735
preproc10_800ms_ssim = 0.3537255118059997
preproc10_800ms_alexnet_2_corr = 0.8511557788944724
preproc10_800ms_alexnet_5_corr = 0.8920603015075378
preproc10_800ms_inceptionv3_avgpool_corr = 0.7116834170854272
preproc10_800ms_clip_final_corr = 0.7815075376884423
preproc10_800ms_efficientnet_avgpool_dist = 0.9051812873382005
preproc10_800ms_swav_avgpool_dist = 0.5725111921876669

preproc10_800ms = np.array([preproc10_800ms_pixcorr, preproc10_800ms_ssim, preproc10_800ms_alexnet_2_corr, preproc10_800ms_alexnet_5_corr, preproc10_800ms_inceptionv3_avgpool_corr, preproc10_800ms_clip_final_corr, preproc10_800ms_efficientnet_avgpool_dist, preproc10_800ms_swav_avgpool_dist])

# %%
ica1_800ms_pixcorr = 0.06850239822701987
ica1_800ms_ssim = 0.447743491501604
ica1_800ms_alexnet_2_corr = 0.6139447236180905
ica1_800ms_alexnet_5_corr = 0.6055025125628141
ica1_800ms_inceptionv3_avgpool_corr = 0.49183417085427134
ica1_800ms_clip_final_corr = 0.5336934673366834
ica1_800ms_efficientnet_avgpool_dist = 0.9815090374183637
ica1_800ms_swav_avgpool_dist = 0.6400723776221275

ica1_800ms = np.array([ica1_800ms_pixcorr, ica1_800ms_ssim, ica1_800ms_alexnet_2_corr, ica1_800ms_alexnet_5_corr, ica1_800ms_inceptionv3_avgpool_corr, ica1_800ms_clip_final_corr, ica1_800ms_efficientnet_avgpool_dist, ica1_800ms_swav_avgpool_dist])

# %%
ica2_800ms_pixcorr = 0.08887378439478467
ica2_800ms_ssim = 0.38204066812269405
ica2_800ms_alexnet_2_corr = 0.6889949748743719
ica2_800ms_alexnet_5_corr = 0.6881658291457287
ica2_800ms_inceptionv3_avgpool_corr = 0.5857286432160804
ica2_800ms_clip_final_corr = 0.5685929648241206
ica2_800ms_efficientnet_avgpool_dist = 0.9710034184483811
ica2_800ms_swav_avgpool_dist = 0.6481600895524025

ica2_800ms = np.array([ica2_800ms_pixcorr, ica2_800ms_ssim, ica2_800ms_alexnet_2_corr, ica2_800ms_alexnet_5_corr, ica2_800ms_inceptionv3_avgpool_corr, ica2_800ms_clip_final_corr, ica2_800ms_efficientnet_avgpool_dist, ica2_800ms_swav_avgpool_dist])

# %%
ica3_800ms_pixcorr = 0.1312965962595004
ica3_800ms_ssim = 0.370353729858061
ica3_800ms_alexnet_2_corr = 0.7184170854271357
ica3_800ms_alexnet_5_corr = 0.7357788944723618
ica3_800ms_inceptionv3_avgpool_corr = 0.5376130653266331
ica3_800ms_clip_final_corr = 0.609070351758794
ica3_800ms_efficientnet_avgpool_dist = 0.9528742008585687
ica3_800ms_swav_avgpool_dist = 0.6355766627937556

ica3_800ms = np.array([ica3_800ms_pixcorr, ica3_800ms_ssim, ica3_800ms_alexnet_2_corr, ica3_800ms_alexnet_5_corr, ica3_800ms_inceptionv3_avgpool_corr, ica3_800ms_clip_final_corr, ica3_800ms_efficientnet_avgpool_dist, ica3_800ms_swav_avgpool_dist])

# %%
ica4_800ms_pixcorr = 0.143927983525235
ica4_800ms_ssim = 0.36416783948470693
ica4_800ms_alexnet_2_corr = 0.7345477386934673
ica4_800ms_alexnet_5_corr = 0.7713819095477387
ica4_800ms_inceptionv3_avgpool_corr = 0.6124371859296482
ica4_800ms_clip_final_corr = 0.640502512562814
ica4_800ms_efficientnet_avgpool_dist = 0.945982133904472
ica4_800ms_swav_avgpool_dist = 0.6217085144668818

ica4_800ms = np.array([ica4_800ms_pixcorr, ica4_800ms_ssim, ica4_800ms_alexnet_2_corr, ica4_800ms_alexnet_5_corr, ica4_800ms_inceptionv3_avgpool_corr, ica4_800ms_clip_final_corr, ica4_800ms_efficientnet_avgpool_dist, ica4_800ms_swav_avgpool_dist])

# %%
ica5_800ms_pixcorr = 0.13754472722331243
ica5_800ms_ssim = 0.3568630290299356
ica5_800ms_alexnet_2_corr = 0.7553266331658292
ica5_800ms_alexnet_5_corr = 0.7883668341708542
ica5_800ms_inceptionv3_avgpool_corr = 0.6006030150753768
ica5_800ms_clip_final_corr = 0.6630653266331658
ica5_800ms_efficientnet_avgpool_dist = 0.9421951065163011
ica5_800ms_swav_avgpool_dist = 0.6214343973994255

ica5_800ms = np.array([ica5_800ms_pixcorr, ica5_800ms_ssim, ica5_800ms_alexnet_2_corr, ica5_800ms_alexnet_5_corr, ica5_800ms_inceptionv3_avgpool_corr, ica5_800ms_clip_final_corr, ica5_800ms_efficientnet_avgpool_dist, ica5_800ms_swav_avgpool_dist])

# %%
ica6_800ms_pixcorr = 0.16225707259231906
ica6_800ms_ssim = 0.3627590068898766
ica6_800ms_alexnet_2_corr = 0.7903517587939699
ica6_800ms_alexnet_5_corr = 0.8343216080402011
ica6_800ms_inceptionv3_avgpool_corr = 0.6424120603015075
ica6_800ms_clip_final_corr = 0.6671608040201005
ica6_800ms_efficientnet_avgpool_dist = 0.9323537431503064
ica6_800ms_swav_avgpool_dist = 0.6079946176707745

ica6_800ms = np.array([ica6_800ms_pixcorr, ica6_800ms_ssim, ica6_800ms_alexnet_2_corr, ica6_800ms_alexnet_5_corr, ica6_800ms_inceptionv3_avgpool_corr, ica6_800ms_clip_final_corr, ica6_800ms_efficientnet_avgpool_dist, ica6_800ms_swav_avgpool_dist])

# %%
ica7_800ms_pixcorr = 0.17441928105867086
ica7_800ms_ssim = 0.3601081864058607
ica7_800ms_alexnet_2_corr = 0.7928140703517589
ica7_800ms_alexnet_5_corr = 0.8365829145728643
ica7_800ms_inceptionv3_avgpool_corr = 0.6378391959798996
ica7_800ms_clip_final_corr = 0.6708040201005026
ica7_800ms_efficientnet_avgpool_dist = 0.9339787039508883
ica7_800ms_swav_avgpool_dist = 0.6044284022599459

ica7_800ms = np.array([ica7_800ms_pixcorr, ica7_800ms_ssim, ica7_800ms_alexnet_2_corr, ica7_800ms_alexnet_5_corr, ica7_800ms_inceptionv3_avgpool_corr, ica7_800ms_clip_final_corr, ica7_800ms_efficientnet_avgpool_dist, ica7_800ms_swav_avgpool_dist])

# %%
ica8_800ms_pixcorr = 0.17539831826868227
ica8_800ms_ssim = 0.35915808384887654
ica8_800ms_alexnet_2_corr = 0.8017085427135678
ica8_800ms_alexnet_5_corr = 0.8333919597989949
ica8_800ms_inceptionv3_avgpool_corr = 0.6230150753768845
ica8_800ms_clip_final_corr = 0.6854522613065327
ica8_800ms_efficientnet_avgpool_dist = 0.9345118822416407
ica8_800ms_swav_avgpool_dist = 0.6011395721137524

ica8_800ms = np.array([ica8_800ms_pixcorr, ica8_800ms_ssim, ica8_800ms_alexnet_2_corr, ica8_800ms_alexnet_5_corr, ica8_800ms_inceptionv3_avgpool_corr, ica8_800ms_clip_final_corr, ica8_800ms_efficientnet_avgpool_dist, ica8_800ms_swav_avgpool_dist])

# %%
ica9_800ms_pixcorr = 0.18451808779259393
ica9_800ms_ssim = 0.35638639423124885
ica9_800ms_alexnet_2_corr = 0.8276130653266331
ica9_800ms_alexnet_5_corr = 0.8697989949748743
ica9_800ms_inceptionv3_avgpool_corr = 0.6669849246231155
ica9_800ms_clip_final_corr = 0.6960804020100503
ica9_800ms_efficientnet_avgpool_dist = 0.921782433083863
ica9_800ms_swav_avgpool_dist = 0.591589918807149

ica9_800ms = np.array([ica9_800ms_pixcorr, ica9_800ms_ssim, ica9_800ms_alexnet_2_corr, ica9_800ms_alexnet_5_corr, ica9_800ms_inceptionv3_avgpool_corr, ica9_800ms_clip_final_corr, ica9_800ms_efficientnet_avgpool_dist, ica9_800ms_swav_avgpool_dist])

# %%
ica10_800ms_pixcorr = 0.18284667368249352
ica10_800ms_ssim = 0.3522191236957545
ica10_800ms_alexnet_2_corr = 0.8244974874371859
ica10_800ms_alexnet_5_corr = 0.8761557788944723
ica10_800ms_inceptionv3_avgpool_corr = 0.6666582914572864
ica10_800ms_clip_final_corr = 0.7154020100502513
ica10_800ms_efficientnet_avgpool_dist = 0.919311367260234
ica10_800ms_swav_avgpool_dist = 0.5906928329914808

ica10_800ms = np.array([ica10_800ms_pixcorr, ica10_800ms_ssim, ica10_800ms_alexnet_2_corr, ica10_800ms_alexnet_5_corr, ica10_800ms_inceptionv3_avgpool_corr, ica10_800ms_clip_final_corr, ica10_800ms_efficientnet_avgpool_dist, ica10_800ms_swav_avgpool_dist])

# %%
ica11_800ms_pixcorr = 0.18519086777708607
ica11_800ms_ssim = 0.3514614833341679
ica11_800ms_alexnet_2_corr = 0.8320100502512563
ica11_800ms_alexnet_5_corr = 0.884321608040201
ica11_800ms_inceptionv3_avgpool_corr = 0.6684673366834171
ica11_800ms_clip_final_corr = 0.7236180904522613
ica11_800ms_efficientnet_avgpool_dist = 0.9205831205329741
ica11_800ms_swav_avgpool_dist = 0.5869125664234162

ica11_800ms = np.array([ica11_800ms_pixcorr, ica11_800ms_ssim, ica11_800ms_alexnet_2_corr, ica11_800ms_alexnet_5_corr, ica11_800ms_inceptionv3_avgpool_corr, ica11_800ms_clip_final_corr, ica11_800ms_efficientnet_avgpool_dist, ica11_800ms_swav_avgpool_dist])

# %%
ica12_800ms_pixcorr = 0.19916186216228426
ica12_800ms_ssim = 0.3515547655980161
ica12_800ms_alexnet_2_corr = 0.8416834170854272
ica12_800ms_alexnet_5_corr = 0.8875125628140704
ica12_800ms_inceptionv3_avgpool_corr = 0.6721105527638191
ica12_800ms_clip_final_corr = 0.7360804020100502
ica12_800ms_efficientnet_avgpool_dist = 0.9187096443703194
ica12_800ms_swav_avgpool_dist = 0.5803991129249334

ica12_800ms = np.array([ica12_800ms_pixcorr, ica12_800ms_ssim, ica12_800ms_alexnet_2_corr, ica12_800ms_alexnet_5_corr, ica12_800ms_inceptionv3_avgpool_corr, ica12_800ms_clip_final_corr, ica12_800ms_efficientnet_avgpool_dist, ica12_800ms_swav_avgpool_dist])

# %%
ica13_800ms_pixcorr = 0.19696479321581792
ica13_800ms_ssim = 0.3509495976061995
ica13_800ms_alexnet_2_corr = 0.8435175879396986
ica13_800ms_alexnet_5_corr = 0.9019597989949749
ica13_800ms_inceptionv3_avgpool_corr = 0.6672361809045226
ica13_800ms_clip_final_corr = 0.7544472361809045
ica13_800ms_efficientnet_avgpool_dist = 0.9157258228652063
ica13_800ms_swav_avgpool_dist = 0.5792615542560816

ica13_800ms = np.array([ica13_800ms_pixcorr, ica13_800ms_ssim, ica13_800ms_alexnet_2_corr, ica13_800ms_alexnet_5_corr, ica13_800ms_inceptionv3_avgpool_corr, ica13_800ms_clip_final_corr, ica13_800ms_efficientnet_avgpool_dist, ica13_800ms_swav_avgpool_dist])

# %%
ica14_800ms_pixcorr = 0.19679772001796408
ica14_800ms_ssim = 0.34810192432565
ica14_800ms_alexnet_2_corr = 0.8408793969849246
ica14_800ms_alexnet_5_corr = 0.8783668341708543
ica14_800ms_inceptionv3_avgpool_corr = 0.6821859296482412
ica14_800ms_clip_final_corr = 0.7530402010050251
ica14_800ms_efficientnet_avgpool_dist = 0.9177711162679043
ica14_800ms_swav_avgpool_dist = 0.581984673589468

ica14_800ms = np.array([ica14_800ms_pixcorr, ica14_800ms_ssim, ica14_800ms_alexnet_2_corr, ica14_800ms_alexnet_5_corr, ica14_800ms_inceptionv3_avgpool_corr, ica14_800ms_clip_final_corr, ica14_800ms_efficientnet_avgpool_dist, ica14_800ms_swav_avgpool_dist])

# %%
ica15_800ms_pixcorr = 0.1982494886922139
ica15_800ms_ssim = 0.3480355728705865
ica15_800ms_alexnet_2_corr = 0.8486683417085427
ica15_800ms_alexnet_5_corr = 0.8844974874371858
ica15_800ms_inceptionv3_avgpool_corr = 0.6946231155778894
ica15_800ms_clip_final_corr = 0.7401758793969848
ica15_800ms_efficientnet_avgpool_dist = 0.9162707625361145
ica15_800ms_swav_avgpool_dist = 0.5800874137878418

ica15_800ms = np.array([ica15_800ms_pixcorr, ica15_800ms_ssim, ica15_800ms_alexnet_2_corr, ica15_800ms_alexnet_5_corr, ica15_800ms_inceptionv3_avgpool_corr, ica15_800ms_clip_final_corr, ica15_800ms_efficientnet_avgpool_dist, ica15_800ms_swav_avgpool_dist])

# %%
ica16_800ms_pixcorr = 0.19706712333085286
ica16_800ms_ssim = 0.347069201519095
ica16_800ms_alexnet_2_corr = 0.8401758793969849
ica16_800ms_alexnet_5_corr = 0.8782160804020099
ica16_800ms_inceptionv3_avgpool_corr = 0.6738442211055277
ica16_800ms_clip_final_corr = 0.7481909547738693
ica16_800ms_efficientnet_avgpool_dist = 0.9143082146541565
ica16_800ms_swav_avgpool_dist = 0.5780967379361391

ica16_800ms = np.array([ica16_800ms_pixcorr, ica16_800ms_ssim, ica16_800ms_alexnet_2_corr, ica16_800ms_alexnet_5_corr, ica16_800ms_inceptionv3_avgpool_corr, ica16_800ms_clip_final_corr, ica16_800ms_efficientnet_avgpool_dist, ica16_800ms_swav_avgpool_dist])

# %%
preproc_800ms_cliptextonly_pixcorr = 0.023471783389911162
preproc_800ms_cliptextonly_ssim = 0.39118807795088656
preproc_800ms_cliptextonly_alexnet_2_corr = 0.6903015075376885
preproc_800ms_cliptextonly_alexnet_5_corr = 0.7808040201005025
preproc_800ms_cliptextonly_inceptionv3_avgpool_corr = 0.6457286432160804
preproc_800ms_cliptextonly_clip_final_corr = 0.6992964824120603
preproc_800ms_cliptextonly_efficientnet_avgpool_dist = 0.9310153468240605
preproc_800ms_cliptextonly_swav_avgpool_dist = 0.628271970152855

preproc_800ms_cliptextonly = np.array([preproc_800ms_cliptextonly_pixcorr, preproc_800ms_cliptextonly_ssim, preproc_800ms_cliptextonly_alexnet_2_corr, preproc_800ms_cliptextonly_alexnet_5_corr, preproc_800ms_cliptextonly_inceptionv3_avgpool_corr, preproc_800ms_cliptextonly_clip_final_corr, preproc_800ms_cliptextonly_efficientnet_avgpool_dist, preproc_800ms_cliptextonly_swav_avgpool_dist])

# %%
preproc_800ms_clipvisiononly_pixcorr = 0.1377477816816349
preproc_800ms_clipvisiononly_ssim = 0.3067890486415341
preproc_800ms_clipvisiononly_alexnet_2_corr = 0.7782663316582915
preproc_800ms_clipvisiononly_alexnet_5_corr = 0.8595979899497488
preproc_800ms_clipvisiononly_inceptionv3_avgpool_corr = 0.6686180904522614
preproc_800ms_clipvisiononly_clip_final_corr = 0.72321608040201
preproc_800ms_clipvisiononly_efficientnet_avgpool_dist = 0.914941371597306
preproc_800ms_clipvisiononly_swav_avgpool_dist = 0.5872416730225086

preproc_800ms_clipvisiononly = np.array([preproc_800ms_clipvisiononly_pixcorr, preproc_800ms_clipvisiononly_ssim, preproc_800ms_clipvisiononly_alexnet_2_corr, preproc_800ms_clipvisiononly_alexnet_5_corr, preproc_800ms_clipvisiononly_inceptionv3_avgpool_corr, preproc_800ms_clipvisiononly_clip_final_corr, preproc_800ms_clipvisiononly_efficientnet_avgpool_dist, preproc_800ms_clipvisiononly_swav_avgpool_dist])

# %%
preproc_800ms_noautokl_pixcorr = 0.103505734423042
preproc_800ms_noautokl_ssim = 0.31586709133659435
preproc_800ms_noautokl_alexnet_2_corr = 0.7940201005025125
preproc_800ms_noautokl_alexnet_5_corr = 0.8564572864321608
preproc_800ms_noautokl_inceptionv3_avgpool_corr = 0.693643216080402
preproc_800ms_noautokl_clip_final_corr = 0.7745226130653267
preproc_800ms_noautokl_efficientnet_avgpool_dist = 0.9114541049400577
preproc_800ms_noautokl_swav_avgpool_dist = 0.5832517866790294

preproc_800ms_noautokl = np.array([preproc_800ms_noautokl_pixcorr, preproc_800ms_noautokl_ssim, preproc_800ms_noautokl_alexnet_2_corr, preproc_800ms_noautokl_alexnet_5_corr, preproc_800ms_noautokl_inceptionv3_avgpool_corr, preproc_800ms_noautokl_clip_final_corr, preproc_800ms_noautokl_efficientnet_avgpool_dist, preproc_800ms_noautokl_swav_avgpool_dist])

# %%
preproc_800ms_nocliptext_pixcorr = 0.18438374535493693
preproc_800ms_nocliptext_ssim = 0.32764150337408465
preproc_800ms_nocliptext_alexnet_2_corr = 0.8381155778894472
preproc_800ms_nocliptext_alexnet_5_corr = 0.888140703517588
preproc_800ms_nocliptext_inceptionv3_avgpool_corr = 0.6800753768844221
preproc_800ms_nocliptext_clip_final_corr = 0.7351005025125628
preproc_800ms_nocliptext_efficientnet_avgpool_dist = 0.9168084813491442
preproc_800ms_nocliptext_swav_avgpool_dist = 0.5907355301082134

preproc_800ms_nocliptext = np.array([preproc_800ms_nocliptext_pixcorr, preproc_800ms_nocliptext_ssim, preproc_800ms_nocliptext_alexnet_2_corr, preproc_800ms_nocliptext_alexnet_5_corr, preproc_800ms_nocliptext_inceptionv3_avgpool_corr, preproc_800ms_nocliptext_clip_final_corr, preproc_800ms_nocliptext_efficientnet_avgpool_dist, preproc_800ms_nocliptext_swav_avgpool_dist])

# %%
preproc_800ms_noclipvision_pixcorr = 0.2288397307698672
preproc_800ms_noclipvision_ssim = 0.4091224125316706
preproc_800ms_noclipvision_alexnet_2_corr = 0.814321608040201
preproc_800ms_noclipvision_alexnet_5_corr = 0.8438442211055277
preproc_800ms_noclipvision_inceptionv3_avgpool_corr = 0.6413819095477388
preproc_800ms_noclipvision_clip_final_corr = 0.7009547738693468
preproc_800ms_noclipvision_efficientnet_avgpool_dist = 0.9351930022578017
preproc_800ms_noclipvision_swav_avgpool_dist = 0.6155729155987502

preproc_800ms_noclipvision = np.array([preproc_800ms_noclipvision_pixcorr, preproc_800ms_noclipvision_ssim, preproc_800ms_noclipvision_alexnet_2_corr, preproc_800ms_noclipvision_alexnet_5_corr, preproc_800ms_noclipvision_inceptionv3_avgpool_corr, preproc_800ms_noclipvision_clip_final_corr, preproc_800ms_noclipvision_efficientnet_avgpool_dist, preproc_800ms_noclipvision_swav_avgpool_dist])

# %%
preproc_null_pixcorr = 0.052989768011088144
preproc_null_ssim = 0.2852038963703765
preproc_null_alexnet_2_corr = 0.5000251256281407
preproc_null_alexnet_5_corr = 0.5308040201005025
preproc_null_inceptionv3_avgpool_corr = 0.4898492462311558
preproc_null_clip_final_corr = 0.4926633165829146
preproc_null_efficientnet_avgpool_dist = 0.975352814238504
preproc_null_swav_avgpool_dist = 0.667968129441142

preproc_null = np.array([preproc_null_pixcorr, preproc_null_ssim, preproc_null_alexnet_2_corr, preproc_null_alexnet_5_corr, preproc_null_inceptionv3_avgpool_corr, preproc_null_clip_final_corr, preproc_null_efficientnet_avgpool_dist, preproc_null_swav_avgpool_dist])

# %%
preproc1r_200ms_pixcorr = 0.15979148236887056
preproc1r_200ms_ssim = 0.3486257222504739
preproc1r_200ms_alexnet_2_corr = 0.8087688442211055
preproc1r_200ms_alexnet_5_corr = 0.8503266331658291
preproc1r_200ms_inceptionv3_avgpool_corr = 0.6304020100502513
preproc1r_200ms_clip_final_corr = 0.67
preproc1r_200ms_efficientnet_avgpool_dist = 0.9341606781062728
preproc1r_200ms_swav_avgpool_dist = 0.6078161073476076

preproc1r_200ms = np.array([preproc1r_200ms_pixcorr, preproc1r_200ms_ssim, preproc1r_200ms_alexnet_2_corr, preproc1r_200ms_alexnet_5_corr, preproc1r_200ms_inceptionv3_avgpool_corr, preproc1r_200ms_clip_final_corr, preproc1r_200ms_efficientnet_avgpool_dist, preproc1r_200ms_swav_avgpool_dist])

# %%
preproc1r_400ms_pixcorr = 0.20710616114105704
preproc1r_400ms_ssim = 0.34892721656660214
preproc1r_400ms_alexnet_2_corr = 0.8539698492462311
preproc1r_400ms_alexnet_5_corr = 0.8886180904522614
preproc1r_400ms_inceptionv3_avgpool_corr = 0.6680150753768844
preproc1r_400ms_clip_final_corr = 0.7442462311557788
preproc1r_400ms_efficientnet_avgpool_dist = 0.9156685800367995
preproc1r_400ms_swav_avgpool_dist = 0.5820944783091545

preproc1r_400ms = np.array([preproc1r_400ms_pixcorr, preproc1r_400ms_ssim, preproc1r_400ms_alexnet_2_corr, preproc1r_400ms_alexnet_5_corr, preproc1r_400ms_inceptionv3_avgpool_corr, preproc1r_400ms_clip_final_corr, preproc1r_400ms_efficientnet_avgpool_dist, preproc1r_400ms_swav_avgpool_dist])

# %%
preproc1r_600ms_pixcorr = 0.20608530241263068
preproc1r_600ms_ssim = 0.34844683114545233
preproc1r_600ms_alexnet_2_corr = 0.8560050251256281
preproc1r_600ms_alexnet_5_corr = 0.9027889447236181
preproc1r_600ms_inceptionv3_avgpool_corr = 0.684497487437186
preproc1r_600ms_clip_final_corr = 0.7504020100502513
preproc1r_600ms_efficientnet_avgpool_dist = 0.911889692505647
preproc1r_600ms_swav_avgpool_dist = 0.5769801105558873

preproc1r_600ms = np.array([preproc1r_600ms_pixcorr, preproc1r_600ms_ssim, preproc1r_600ms_alexnet_2_corr, preproc1r_600ms_alexnet_5_corr, preproc1r_600ms_inceptionv3_avgpool_corr, preproc1r_600ms_clip_final_corr, preproc1r_600ms_efficientnet_avgpool_dist, preproc1r_600ms_swav_avgpool_dist])

# %%
preproc1r_800ms_pixcorr = 0.2037024803897124
preproc1r_800ms_ssim = 0.34841002203035737
preproc1r_800ms_alexnet_2_corr = 0.8528140703517588
preproc1r_800ms_alexnet_5_corr = 0.8913567839195979
preproc1r_800ms_inceptionv3_avgpool_corr = 0.6840954773869347
preproc1r_800ms_clip_final_corr = 0.7478140703517587
preproc1r_800ms_efficientnet_avgpool_dist = 0.9118347599654225
preproc1r_800ms_swav_avgpool_dist = 0.5756172850728035

preproc1r_800ms = np.array([preproc1r_800ms_pixcorr, preproc1r_800ms_ssim, preproc1r_800ms_alexnet_2_corr, preproc1r_800ms_alexnet_5_corr, preproc1r_800ms_inceptionv3_avgpool_corr, preproc1r_800ms_clip_final_corr, preproc1r_800ms_efficientnet_avgpool_dist, preproc1r_800ms_swav_avgpool_dist])

# %%
meg_1s_pixcorr = 0.16009165118360558
meg_1s_ssim = 0.3394612284595564
meg_1s_alexnet_2_corr = 0.8252763819095477
meg_1s_alexnet_5_corr = 0.8796482412060302
meg_1s_inceptionv3_avgpool_corr = 0.7193216080402011
meg_1s_clip_final_corr = 0.7999497487437186
meg_1s_efficientnet_avgpool_dist = 0.9032268859994655
meg_1s_swav_avgpool_dist = 0.5564384427666664

meg_1s = np.array([meg_1s_pixcorr, meg_1s_ssim, meg_1s_alexnet_2_corr, meg_1s_alexnet_5_corr, meg_1s_inceptionv3_avgpool_corr, meg_1s_clip_final_corr, meg_1s_efficientnet_avgpool_dist, meg_1s_swav_avgpool_dist])

# %%
meg_200ms_pixcorr = 0.10763443754793237
meg_200ms_ssim = 0.3468386473408151
meg_200ms_alexnet_2_corr = 0.7443718592964824
meg_200ms_alexnet_5_corr = 0.7707788944723618
meg_200ms_inceptionv3_avgpool_corr = 0.5863065326633166
meg_200ms_clip_final_corr = 0.6510050251256282
meg_200ms_efficientnet_avgpool_dist = 0.9531593043377506
meg_200ms_swav_avgpool_dist = 0.6170940177887678

meg_200ms = np.array([meg_200ms_pixcorr, meg_200ms_ssim, meg_200ms_alexnet_2_corr, meg_200ms_alexnet_5_corr, meg_200ms_inceptionv3_avgpool_corr, meg_200ms_clip_final_corr, meg_200ms_efficientnet_avgpool_dist, meg_200ms_swav_avgpool_dist])

# %%
meg_400ms_pixcorr = 0.12855215618443175
meg_400ms_ssim = 0.34465929622644026
meg_400ms_alexnet_2_corr = 0.7978391959798995
meg_400ms_alexnet_5_corr = 0.8492713567839196
meg_400ms_inceptionv3_avgpool_corr = 0.6633668341708542
meg_400ms_clip_final_corr = 0.7535678391959799
meg_400ms_efficientnet_avgpool_dist = 0.920219879093711
meg_400ms_swav_avgpool_dist = 0.573104911223054

meg_400ms = np.array([meg_400ms_pixcorr, meg_400ms_ssim, meg_400ms_alexnet_2_corr, meg_400ms_alexnet_5_corr, meg_400ms_inceptionv3_avgpool_corr, meg_400ms_clip_final_corr, meg_400ms_efficientnet_avgpool_dist, meg_400ms_swav_avgpool_dist])

# %%
meg_600ms_pixcorr = 0.12969556939225552
meg_600ms_ssim = 0.34363336770230246
meg_600ms_alexnet_2_corr = 0.7949748743718592
meg_600ms_alexnet_5_corr = 0.8632663316582914
meg_600ms_inceptionv3_avgpool_corr = 0.6884422110552764
meg_600ms_clip_final_corr = 0.7915577889447236
meg_600ms_efficientnet_avgpool_dist = 0.9121938878114452
meg_600ms_swav_avgpool_dist = 0.5642137861251831

meg_600ms = np.array([meg_600ms_pixcorr, meg_600ms_ssim, meg_600ms_alexnet_2_corr, meg_600ms_alexnet_5_corr, meg_600ms_inceptionv3_avgpool_corr, meg_600ms_clip_final_corr, meg_600ms_efficientnet_avgpool_dist, meg_600ms_swav_avgpool_dist])

# %%
meg_800ms_pixcorr = 0.15678886758267482
meg_800ms_ssim = 0.34914710350512473
meg_800ms_alexnet_2_corr = 0.815678391959799
meg_800ms_alexnet_5_corr = 0.8803517587939699
meg_800ms_inceptionv3_avgpool_corr = 0.7532412060301508
meg_800ms_clip_final_corr = 0.8124874371859296
meg_800ms_efficientnet_avgpool_dist = 0.8980043624923565
meg_800ms_swav_avgpool_dist = 0.5565412705391646

meg_800ms = np.array([meg_800ms_pixcorr, meg_800ms_ssim, meg_800ms_alexnet_2_corr, meg_800ms_alexnet_5_corr, meg_800ms_inceptionv3_avgpool_corr, meg_800ms_clip_final_corr, meg_800ms_efficientnet_avgpool_dist, meg_800ms_swav_avgpool_dist])

# %%
meta_pixcorr = 0.088
meta_ssim = 0.333
meta_alexnet_2_corr = 0.747
meta_alexnet_5_corr = 0.855
meta_inceptionv3_avgpool_corr = 0.712
meta_clip_final_corr = 0.804
meta_efficientnet_avgpool_dist = 0
meta_swav_avgpool_dist = 0.576

meta = np.array([meta_pixcorr, meta_ssim, meta_alexnet_2_corr, meta_alexnet_5_corr, meta_inceptionv3_avgpool_corr, meta_clip_final_corr, meta_efficientnet_avgpool_dist, meta_swav_avgpool_dist])

# %%
ozcelik_pixcorr = 0.305
ozcelik_ssim = 0.367
ozcelik_alexnet_2_corr = 0.967
ozcelik_alexnet_5_corr = 0.974
ozcelik_inceptionv3_avgpool_corr = 0.878
ozcelik_clip_final_corr = 0.925
ozcelik_efficientnet_avgpool_dist = 0.768
ozcelik_swav_avgpool_dist = 0.415

ozcelik = np.array([ozcelik_pixcorr, ozcelik_ssim, ozcelik_alexnet_2_corr, ozcelik_alexnet_5_corr, ozcelik_inceptionv3_avgpool_corr, ozcelik_clip_final_corr, ozcelik_efficientnet_avgpool_dist, ozcelik_swav_avgpool_dist])

# %%
scotti_pixcorr = 0.206
scotti_ssim = 0.303
scotti_alexnet_2_corr = 0.921
scotti_alexnet_5_corr = 0.972
scotti_inceptionv3_avgpool_corr = 0.948
scotti_clip_final_corr = 0.951
scotti_efficientnet_avgpool_dist = 0.63
scotti_swav_avgpool_dist = 0.36

scotti = np.array([scotti_pixcorr, scotti_ssim, scotti_alexnet_2_corr, scotti_alexnet_5_corr, scotti_inceptionv3_avgpool_corr, scotti_clip_final_corr, scotti_efficientnet_avgpool_dist, scotti_swav_avgpool_dist])

# %% [markdown]
# ### plots

# %%
# Define the bar width
bar_width = 0.06

# Define the x values for the bar plots
x = np.arange(len(avg1_200ms))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]
x4 = [x + bar_width for x in x3]
x5 = [x + bar_width for x in x4]
x6 = [x + bar_width for x in x5]
x7 = [x + bar_width for x in x6]
x8 = [x + bar_width for x in x7]
x9 = [x + bar_width for x in x8]
x10 = [x + bar_width for x in x9]
x11 = [x + bar_width for x in x10]
x12 = [x + bar_width for x in x11]
x13 = [x + bar_width for x in x12]
x14 = [x + bar_width for x in x13]

# Plot the bar plots
plt.bar(x1, preproc_null, color='purple', width=bar_width, label='chance level')
plt.bar(x2, avg1_200ms, color='b', width=bar_width, label='200ms')
plt.bar(x3, avg1_400ms, color='g', width=bar_width, label='400ms')
plt.bar(x4, avg1_600ms, color='r', width=bar_width, label='600ms')
plt.bar(x5, avg1_800ms, color='c', width=bar_width, label='800ms')
plt.bar(x6, preproc_200ms, color='m', width=bar_width, label='200ms preproc')
plt.bar(x7, preproc_400ms, color='y', width=bar_width, label='400ms preproc')
plt.bar(x8, preproc_600ms, color='k', width=bar_width, label='600ms preproc')
plt.bar(x9, preproc_800ms, color='orange', width=bar_width, label='800ms preproc')
plt.bar(x10, meg_200ms, color='brown', width=bar_width, label='MEG 200ms')
plt.bar(x11, meg_400ms, color='grey', width=bar_width, label='MEG 400ms')
plt.bar(x12, meg_600ms, color='olive', width=bar_width, label='MEG 600ms')
plt.bar(x13, meg_800ms, color='cyan', width=bar_width, label='MEG 800ms')
plt.bar(x14, meg_1s, color='pink', width=bar_width, label='MEG 1s')


# Define the labels for the x-axis
labels = ['PixCorr↑', 'SSIM↑', 'Alex(2)↑', 'Alex(5)↑', 'Incep↑', 'CLIP↑', 'Eff↓', 'SwAV↓']  # replace with your actual labels

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)

# Add a legend
plt.legend()
plt.ylim(0, 1)

# Display the plot
plt.show()

# %%
# Define the bar width
bar_width = 0.25

# Define the x values for the bar plots
x = np.arange(len(meta[:-2]))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]

# Plot the bar plots
plt.bar(x1, meg_1s[:-2], color='r', width=bar_width, label='Our model')
plt.bar(x2, meta[:-2], color='g', width=bar_width, label='Benchetrit et al. (2023) *')
plt.bar(x3, preproc_null[:-2], color='b', width=bar_width, label='chance level **')


# Define the labels for the x-axis
labels = ['PixCorr', 'SSIM', 'Alex(2)', 'Alex(5)', 'Incep', 'CLIP']  # replace with your actual labels

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)

# Add a legend
plt.legend()

plt.title('Our Image Reconstruction Performance')
plt.ylabel('Correlation')
plt.xlabel('Metric')
plt.ylim(0, 1)

# Display the plot
plt.show()

# %%
# Define the bar width
bar_width = 0.1

# Define the x values for the bar plots
x = np.arange(len(preproc_null))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]
x4 = [x + bar_width for x in x3]
x5 = [x + bar_width for x in x4]
x6 = [x + bar_width for x in x5]
x7 = [x + bar_width for x in x6]

# Plot the bar plots
plt.bar(x1, preproc_null, color='b', width=bar_width, label='chance level')
plt.bar(x2, preproc_800ms_cliptextonly, color='r', width=bar_width, label='CLIP text only')
plt.bar(x3, preproc_800ms_noclipvision, color='y', width=bar_width, label='no clip vision')
plt.bar(x4, preproc_800ms_clipvisiononly, color='g', width=bar_width, label='CLIP vision only')
plt.bar(x5, preproc_800ms_nocliptext, color='m', width=bar_width, label='no clip text')
plt.bar(x6, preproc_800ms_noautokl, color='c', width=bar_width, label='no auto KL')
plt.bar(x7, preproc_800ms, color='k', width=bar_width, label='full model')


# Define the labels for the x-axis
labels = ['PixCorr↑', 'SSIM↑', 'Alex(2)↑', 'Alex(5)↑', 'Incep↑', 'CLIP↑', 'Eff↓', 'SwAV↓']

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Ablation Image Reconstruction Performance 800ms')
plt.ylabel('Correlation')
plt.xlabel('Metric')
plt.ylim(0, 1)

# Display the plot
plt.show()

# %%
# Define the bar width
bar_width = 0.15

# Define the x values for the bar plots
x = np.arange(len(avg1_200ms))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]
x4 = [x + bar_width for x in x3]
x5 = [x + bar_width for x in x4]
# x6 = [x + bar_width for x in x5]
# x7 = [x + bar_width for x in x6]
# x8 = [x + bar_width for x in x7]

# Plot the bar plots
plt.bar(x1, preproc_null, color='r', width=bar_width, label='chance level')
# plt.bar(x2, avg1_200ms, color='b', width=bar_width, label='200ms')
# plt.bar(x3, avg1_400ms, color='g', width=bar_width, label='400ms')
# plt.bar(x4, avg1_600ms, color='r', width=bar_width, label='600ms')
# plt.bar(x5, avg1_800ms, color='c', width=bar_width, label='800ms')
plt.bar(x2, preproc_200ms, color='g', width=bar_width, label='first 200ms')
plt.bar(x3, preproc_400ms, color='b', width=bar_width, label='first 400ms')
plt.bar(x4, preproc_600ms, color='c', width=bar_width, label='first 600ms')
plt.bar(x5, preproc_800ms, color='orange', width=bar_width, label='first 800ms')
# plt.bar(x6, meg_1s, color='pink', width=bar_width, label='THINGS-MEG')
# plt.bar(x7, ozcelik, color='brown', width=bar_width, label='Ozcelik et al. (2023)')
# plt.bar(x8, scotti, color='grey', width=bar_width, label='Scotti et al. (2023)')


# Define the labels for the x-axis
labels = ['PixCorr↑', 'SSIM↑', 'Alex(2)↑', 'Alex(5)↑', 'Incep↑', 'CLIP↑', 'Eff↓', 'SwAV↓']  # replace with your actual labels

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)

# Add a legend
plt.legend()
plt.title('Subject 1 Performance Across Durations')
plt.ylabel('Correlation')
plt.xlabel('Metric')
plt.ylim(0, 1)

# Display the plot
plt.show()

# %%
# Define the bar width
bar_width = 0.2

# Define the x values for the bar plots
x = np.arange(len(avg1_200ms))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]
x4 = [x + bar_width for x in x3]
# x5 = [x + bar_width for x in x4]
# x6 = [x + bar_width for x in x5]
# x7 = [x + bar_width for x in x6]
# x8 = [x + bar_width for x in x7]

# Plot the bar plots
plt.bar(x1, preproc_null, color='r', width=bar_width, label='chance level')
# plt.bar(x2, avg1_200ms, color='b', width=bar_width, label='200ms')
# plt.bar(x3, avg1_400ms, color='g', width=bar_width, label='400ms')
# plt.bar(x4, avg1_600ms, color='r', width=bar_width, label='600ms')
# plt.bar(x5, avg1_800ms, color='c', width=bar_width, label='800ms')
# plt.bar(x2, preproc_200ms, color='g', width=bar_width, label='subject 1 200ms preprocessed')
# plt.bar(x3, preproc_400ms, color='b', width=bar_width, label='subject 1 400ms preprocessed')
# plt.bar(x4, preproc_600ms, color='c', width=bar_width, label='subject 1 600ms preprocessed')
plt.bar(x2, preproc_800ms, color='orange', width=bar_width, label='THINGS-EEG2 subject 1')
plt.bar(x3, meg_1s, color='g', width=bar_width, label='Benchetrit et al. (2023) THINGS-MEG')
# plt.bar(x7, ozcelik, color='brown', width=bar_width, label='Ozcelik et al. (2023) NSD(fMRI)')
plt.bar(x4, scotti, color='b', width=bar_width, label='Scotti et al. (2023) NSD(fMRI)')


# Define the labels for the x-axis
labels = ['PixCorr↑', 'SSIM↑', 'Alex(2)↑', 'Alex(5)↑', 'Incep↑', 'CLIP↑', 'Eff↓', 'SwAV↓']  # replace with your actual labels

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Performance Put In Context')
plt.ylabel('Correlation')
plt.xlabel('Metric')
plt.ylim(0, 1)

# Display the plot
plt.show()

# %%
# Define the bar width
bar_width = 0.08

# Define the x values for the bar plots
x = np.arange(len(preproc_800ms))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]
x4 = [x + bar_width for x in x3]
x5 = [x + bar_width for x in x4]
x6 = [x + bar_width for x in x5]
x7 = [x + bar_width for x in x6]
x8 = [x + bar_width for x in x7]
x9 = [x + bar_width for x in x8]
x10 = [x + bar_width for x in x9]

# Plot the bar plots
plt.bar(x1, preproc_800ms, color='orange', width=bar_width, label='subject 1')
plt.bar(x2, preproc2_800ms, color='r', width=bar_width, label='subject 2')
plt.bar(x3, preproc3_800ms, color='g', width=bar_width, label='subject 3')
plt.bar(x4, preproc4_800ms, color='b', width=bar_width, label='subject 4')
plt.bar(x5, preproc5_800ms, color='c', width=bar_width, label='subject 5')
plt.bar(x6, preproc6_800ms, color='m', width=bar_width, label='subject 6')
plt.bar(x7, preproc7_800ms, color='y', width=bar_width, label='subject 7')
plt.bar(x8, preproc8_800ms, color='k', width=bar_width, label='subject 8')
plt.bar(x9, preproc9_800ms, color='pink', width=bar_width, label='subject 9')
plt.bar(x10, preproc10_800ms, color='brown', width=bar_width, label='subject 10')


# Define the labels for the x-axis
labels = ['PixCorr↑', 'SSIM↑', 'Alex(2)↑', 'Alex(5)↑', 'Incep↑', 'CLIP↑', 'Eff↓', 'SwAV↓']  # replace with your actual labels

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)
plt.ylim(0, 1)

# Add a legend
plt.legend()

plt.title('Performance Across Subjects')
plt.ylabel('Correlation')
plt.xlabel('Metric')

# Display the plot
plt.show()

# %%
# Define the bar width
bar_width = 0.04

# Define the x values for the bar plots
x = np.arange(len(preproc_800ms))

x1 = x
x2 = [x + bar_width for x in x1]
x3 = [x + bar_width for x in x2]
x4 = [x + bar_width for x in x3]
x5 = [x + bar_width for x in x4]
x6 = [x + bar_width for x in x5]
x7 = [x + bar_width for x in x6]
x8 = [x + bar_width for x in x7]
x9 = [x + bar_width for x in x8]
x10 = [x + bar_width for x in x9]
x11 = [x + bar_width for x in x10]
x12 = [x + bar_width for x in x11]
x13 = [x + bar_width for x in x12]
x14 = [x + bar_width for x in x13]
x15 = [x + bar_width for x in x14]
x16 = [x + bar_width for x in x15]
x17 = [x + bar_width for x in x16]
x18 = [x + bar_width for x in x17]

# Plot the bar plots
plt.bar(x1, preproc_null, color='r', width=bar_width, label='chance level')
plt.bar(x2, ica1_800ms, color='orange', width=bar_width, label='top 1 ICs')
plt.bar(x3, ica2_800ms, color='g', width=bar_width, label='top 2 ICs')
plt.bar(x4, ica3_800ms, color='b', width=bar_width, label='top 3 ICs')
plt.bar(x5, ica4_800ms, color='c', width=bar_width, label='top 4 ICs')
plt.bar(x6, ica5_800ms, color='m', width=bar_width, label='top 5 ICs')
plt.bar(x7, ica6_800ms, color='y', width=bar_width, label='top 6 ICs')
plt.bar(x8, ica7_800ms, color='k', width=bar_width, label='top 7 ICs')
plt.bar(x9, ica8_800ms, color='pink', width=bar_width, label='top 8 ICs')
plt.bar(x10, ica9_800ms, color='brown', width=bar_width, label='top 9 ICs')
plt.bar(x11, ica10_800ms, color='grey', width=bar_width, label='top 10 ICs')
plt.bar(x12, ica11_800ms, color='olive', width=bar_width, label='top 11 ICs')
plt.bar(x13, ica12_800ms, color='cyan', width=bar_width, label='top 12 ICs')
plt.bar(x14, ica13_800ms, color='purple', width=bar_width, label='top 13 ICs')
plt.bar(x15, ica14_800ms, color='r', width=bar_width, label='top 14 ICs')
plt.bar(x16, ica15_800ms, color='g', width=bar_width, label='top 15 ICs')
plt.bar(x17, ica16_800ms, color='b', width=bar_width, label='top 16 ICs')
plt.bar(x18, preproc_800ms, color='c', width=bar_width, label='original')



# Define the labels for the x-axis
labels = ['PixCorr↑', 'SSIM↑', 'Alex(2)↑', 'Alex(5)↑', 'Incep↑', 'CLIP↑', 'Eff↓', 'SwAV↓']  # replace with your actual labels

# Set the current tick locations and labels of the x-axis
plt.xticks(x + bar_width, labels)

# Add a legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('Cumulative ICs Peformance')
plt.ylabel('Correlation')
plt.xlabel('Metric')
plt.ylim(0, 1)

# Display the plot
plt.show()
